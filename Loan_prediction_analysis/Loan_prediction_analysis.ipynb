# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Dataset

# %%
#https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset
df = pd.read_csv("Loan_prediction_train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#find the null values 
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#filling in the missing values for numeric attributes
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
#now for categorical attributes mode can be used
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#EDA
# Plot the count of each gender using seaborn's countplot
#Categorical attributes visualization
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['Married'])
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(x='Education', data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Self_Employed', data=df)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(x='Property_Area', data=df)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
sns.countplot(x=df['Dependents'])
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(x=df['Loan_Status'])
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
#numerical attributes visualization
sns.distplot(df['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sns.distplot(df['Credit_History'])
# Out:
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
#creating new attributes
df['TotalIncome'] =df['ApplicantIncome'] + df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  TotalIncome
# 0             1.0         Urban           Y       5849.0
# ...

# %%
#apply log transformation to attribute because it is too much left skewed
df['ApplicantIncome_log'] = np.log(df['ApplicantIncome'])
sns.distplot(x=df['ApplicantIncome_log'])
# Out:
# <Axes: ylabel='Density'>

# %%
df['CoapplicantIncome_log'] = np.log(df['CoapplicantIncome'])
sns.displot(x=df['CoapplicantIncome_log'])

# %%
df['LoanAmount_log'] = np.log(df['LoanAmount'])
sns.distplot(x=df['LoanAmount_log'])
# Out:
# <Axes: ylabel='Density'>

# %%
df['Loan_Amount_Term_log'] = np.log(df['Loan_Amount_Term'])
sns.distplot(x=df['Loan_Amount_Term_log'])
# Out:
# <Axes: ylabel='Density'>

# %%
df['TotalIncome_log'] = np.log(df['TotalIncome'])
sns.distplot(x=df['TotalIncome_log'])
# Out:
# <Axes: ylabel='Density'>

# %%
#correlation 
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True , cmap='Reds')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  TotalIncome  ApplicantIncome_log  \
# ...

# %%
#drop unnecessary columns
cols = ['ApplicantIncome' , 'CoapplicantIncome' , 'LoanAmount' , 'Loan_Amount_Term' , 'TotalIncome' , 'Loan_ID' , 'CoapplicantIncome_log']
df = df.drop(columns=cols , axis=1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncome_log  LoanAmount_log  \
# 0         Urban           Y             8.674026        4.986426
# 1         Rural           N             8.430109        4.852030
# 2         Urban           Y             8.006368        4.189655
# 3         Urban           Y             7.856707        4.787492
# 4         Urban           Y             8.699515        4.948760
#
#    Loan_Amount_Term_log  TotalIncome_log
# 0              5.886104         8.674026
# 1              5.886104         8.714568
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender' , 'Married' , 'Education' , 'Self_Employed' , 'Property_Area' , 'Loan_Status','Dependents']
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncome_log  LoanAmount_log  \
# 0              2            1             8.674026        4.986426
# 1              0            0             8.430109        4.852030
# 2              2            1             8.006368        4.189655
# 3              2            1             7.856707        4.787492
# 4              2            1             8.699515        4.948760
#
#    Loan_Amount_Term_log  TotalIncome_log
# 0              5.886104         8.674026
# ...

# %%
#Training testing
x = df.drop(columns = ['Loan_Status'],axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split

# %%
#model training
from sklearn.model_selection import cross_val_score
def classify(model,x,y):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20 , random_state=42)
    model.fit(x_train,y_train)
    print("Accuracy : ",model.score(x_test,y_test)*100)
    #cross validation - it is used for better validation of model
    score = cross_val_score(model,x,y,cv=5)
    print("Cross Validation : ",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
classify(model1,x,y)
# Out:
# Accuracy :  78.86178861788618
# Cross Validation :  80.9462881514061

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
classify(model2,x,y)
# Out:
# Accuracy :  69.91869918699187
# Cross Validation :  70.8516593362655

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model3 = RandomForestClassifier()
classify(model3,x,y)
# Out:
# Accuracy :  78.04878048780488
# Cross Validation :  78.01412768226042

# %%
model4 = ExtraTreesClassifier()
classify(model4,x,y)
# Out:
# Accuracy :  73.17073170731707
# Cross Validation :  76.06424097027855

# %%
#hyperparameter tuning
model3 = RandomForestClassifier(n_estimators=100,min_samples_split=25,max_depth=7,max_features=1)
classify(model3,x,y)
# Out:
# Accuracy :  78.04878048780488
# Cross Validation :  80.45848327335733

# %% [markdown]
# #confusion matrix - A confusion matrix is a summary of prediction results on a classification problem. The number of correct and incorrect predictions are summarized with count values and broken down by each class. It gives us insight not only into the errors being made by a classifier but more importantly the types of errors that are being made.

# %%
x_train['Dependents'] = le.fit_transform(x_train['Dependents'])
x_test['Dependents'] = le.fit_transform(x_test['Dependents'])
model5 = RandomForestClassifier()
model5.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix
y_pred = model5.predict(x_test)
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[18, 25],
#        [ 2, 78]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
import pickle
filename = 'savedRFloan.sav'
pickle.dump(model5,open(filename,'wb'))

# %%
load_model = pickle.load(open(filename,'rb'))

# %%
x.head(3)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
#
#    Property_Area  ApplicantIncome_log  LoanAmount_log  Loan_Amount_Term_log  \
# 0              2             8.674026        4.986426              5.886104
# 1              0             8.430109        4.852030              5.886104
# 2              2             8.006368        4.189655              5.886104
#
#    TotalIncome_log
# 0         8.674026
# 1         8.714568
# 2         8.006368

# %%
load_model.predict([[1,1,0,0,1,1,2,8.006368,4.189655,5.886104,8.006368]])
# Out:
# array([1])
